# %% [markdown]
# # Chapter 1
# ### Your first day at your new job 👩‍💻👨‍💻
#
# You are starting a new job as a junior software developer in an IT company.
#
# The company’s HR department asks you to fill out a form, so you start by assigning your personal information to corresponding variables.
#
# 📌 Create a variable for your name, surname, age, ID number, place of residence, to specify if you have active health insurance or not, and lastly one for specifying your nationality.

# %%
#Please assign your personal information to variables
name = "Fatma"
surname = "Akpunar"
age = "22"
ıd_number = "123456789"
live = "İstanbul"
healt_insurance = True
my_nationaly = "Turkish"

# %% [markdown]
# ###Meet And Greet
# Introduce yourself to your new co-workers.
#
# 📌 Use a f-string to print "My name is Joey Tribbiani I am 25 years old and I live in London”.

# %%
#Write a sentence using the print function to describe yourself using the variables above in the correct data type
print (f"My name is {name} {surname} I am {age} years old I live in {live}")
# Out:
# My name is Fatma Akpunar I am 22 years old I live in İstanbul

# %% [markdown]
# ### Equipment starter pack
# The HR department asks you to list the items you would need to improve your work efficiency
#
# Mandatory:
# * Laptop
# * Headset
# * Second monitor
#
# Optional:
# * Mousepad
# * USB drive
# * External drive
#
#
# 📌 Create a shopping list that contains items above and print it.

# %%
#Create the item_list
item_list = ['Laptop', 'Headset','Second monitor', 'Mousepad', 'USB driver', 'External drive']

# %%
#Print the list
print(item_list)
# Out:
# ['Laptop', 'Headset', 'Second monitor', 'Mousepad', 'USB driver', 'External drive']

# %% [markdown]
# ####What is mandatory and what is optional?
#
# 📌 Use list slicing to devide your list in two list: 'mandatory_item_list' and 'optional_item_list' and print both to the screen.

# %%
#Use list slicing to divide the mandatory items
mandatory_item_list = item_list[0:3]

# %%
#Use list slicing to divide the optional items
optimal_item_list = item_list[3:6]

# %%
#Print both to the screen
print(mandatory_item_list)
print(optimal_item_list)
# Out:
# ['Laptop', 'Headset', 'Second monitor']
# ['Mousepad', 'USB driver', 'External drive']

# %% [markdown]
# #### Go Shopping
# Next, you will have to go and purchase these items, the finance department confirmed a budget of $5000.
#
# 📌 Assign 5000 to a variable called limit, so you know how much you can spend.

# %%
#Assign the spending limit value to a variable called limit
limit = 5000

# %% [markdown]
# ####Price dictionary
#
# Before you start shopping yo need to find the best items that you can buy within the company budget.
#
# 📌 Prepare a dictionary called “price_sheet” that includes the items as keys and the prices as values.

# %%
#Create a dictionary that contains each item and its price
price_sheet = {
    'Laptop' : 1500,
    'Headset': 100,
    'Second monitor' : 200,
    'Mousepad' : 50,
    'USB Drive' : 70,
    'External drive' : 250
}

# %% [markdown]
# ####Shopping functions
#
# You need to define three functions that will help you during shopping.
#
# 📌 First, create an empty list that  will be your shopping cart. Here you will add the items you need to purchase.
#
# 1. Define a function for both adding items to the cart and removing them from the item_list.
#
# 📌 The "add_to_cart" function should take the item name and the quantity to buy as an argument.
#
# 2. Define a function that will create an invoice.
#
# 📌 The "create_invoice" function should calculate the taxes of each item (18%) and add it to the total amount.
#
# 3. Define a function for the checkout.
#
# 📌 The "checkout" function should subtract the total amount from the budget and print a statement to inform if the payment was successful.

# %%
#Initialize the cart list (Öncelikle sepetimiz olarak kullanabileceğimiz boş bir liste oluşturuyoruz)
cart = [] #boş liste sepetimiz satın alacağımız eşyaları ekliyeceğiz

# %%
#Define the "add_to_cart" function
def add_to_cart(item, quantity):
   cart.append((item, quantity))
   item_list.remove(item)

# %%
#Define the "create_invoice" function fatura oluşturalım
def create_invoice():
    total_amount_inc_tax = 0
    for item, quantity in cart:
        price = price_sheet[item]
        tax = 0.18 * price
        total = (tax + price) * quantity
        total_amount_inc_tax += tax
        print('item:',item, '\t',  'price:', price, '\t', 'quantity:', quantity, '\t', 'tax:', tax, '\t', 'total:', total, '\n')

    print('After the taxes are applied the total amount is:', '\t', total_amount_inc_tax)

    return total_amount_inc_tax

# %%
#Define the "checkout" function
def checkout():
        global limit
        total_amount = create_invoice()
        if limit == 0:
            print("you don't have any budget ")
        elif total_amount > limit:
            print("The amount you have to pay is above the pending limit, you need to drop some items.")
        else:
            limit -= total_amount
            print(f"the total amount ( incl taxes ) you've paid in {total_amount}. You have  {limit} dollars left.")

# %%
add_to_cart("Laptop", 1)
add_to_cart("Headset", 8)
add_to_cart("Second monitor", 1)
add_to_cart("Mousepad", 1)
add_to_cart("USB Driver", 2)
add_to_cart("External drive", 4)
checkout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-7324fd7c1ff7> in <module>
# ----> 1 add_to_cart("Laptop", 1)
#       2 add_to_cart("Headset", 8)
#       3 add_to_cart("Second monitor", 1)
#       4 add_to_cart("Mousepad", 1)
#       5 add_to_cart("USB Driver", 2)
#
# <ipython-input-169-3a2a7ca6fac2> in add_to_cart(item, quantity)
#       2 def add_to_cart(item, quantity):
#       3    cart.append((item, quantity))
# ----> 4    item_list.remove(item)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# Let's shop!

# %% [markdown]
# ###Game Night
#
# You are back at the office and the HR department organizes a welcome party for new employees.
#
# You decide to create a Rock-Paper-Scissor game.
#
# 📌 Create a Rock-Paper-Scissor game in which the user plays against the computer. The player will choose one of the actions, and the computer will choose its action randomly.

# %%
#Import the random library
import random

# %%
#create a list containing the three actions of the game.
acttion_list = ['rock', 'paper', 'scissors']

# %%
#Set the scores of players to 0
computer_score = 0
player_score = 0

#Ask the user how many rounds they want to play
total_rounds = input("kaç tur oynamak istersiniz?")

#Add a round_counter that is 0 at the beginning
round_counter = 0

#Write a while loop and put the game inside
while True:


  #Increase round_counter by and print it
  round_counter += 1
  print("round number:", round_counter)
  

  #Select a random action for computer
  computer_choice = random.choice(acttion_list)

  #Ask player to choose an action
  player_choice = input("lütfen işleminizi seçin:")

  #Print the players choices
  print("computer:", computer_choice)
  print("Player", player_choice)



  #tie condition
  if computer_choice == player_choice:
    print("uyarı! her iki oyuncu da aynı eylemi seçti.")


  #Remaining conditions
  elif computer_choice == 'paper' :
    if player_choice == 'rock':
      print("kazanan : computer")
      computer_score += 1
    else:
      print("kazanan : oyuncu")
      player_score += 1

  elif computer_choice == 'rock':
    if player_choice == 'paper':
       print("kazanan : oyuncu")
       player_score += 1
    else:
        print("kazanan : computer")
        computer_score += 1

  elif computer_choice == 'scissors':
    if player_choice == 'paper':
       print("kazanan: computer")
       computer_score += 1
    else:
      print("kazanan: oyuncu")
      player_score += 1
  

  #Stop the while loop if the round_counter equals the number of total rounds
  if round_counter == int(total_rounds):
    break


#Print the outcome of the game by using conditional statements
if computer_score == player_score:
  print("kazanan  yok", computer_score, ":", player_score )
elif computer_score > player_score:
  print("bilgisayar skorla kazandı", computer_score, ":", player_score)
elif computer_score < player_score:
  print("oyuncu scorla kazandı", computer_score, ":", player_score)
# Out:
# kaç tur oynamak istersiniz?3
# round number: 1
# lütfen işleminizi seçin:rock
# computer: paper
# Player rock
# kazanan : computer
# round number: 2
# lütfen işleminizi seçin:scissors
# computer: rock
# Player scissors
# kazanan : computer
# round number: 3
# lütfen işleminizi seçin:paper
# computer: rock
# Player paper
# kazanan : oyuncu
# bilgisayar skorla kazandı 2 : 1

# %% [markdown]
# # Your first task
#
# Rachel asks you to write a program to track the name and revenue each employee brings.
#
# * Create the "salesperson_revenue" dictionary to see the employee name as a key and the revenue as a value.
#
#   📌 Every employee starts with 0 revenue.
# * Define the "enter_revenue" function.
#
#   📌 The function takes the name and revenue as an argument and updates the salesperson_revenue dictionary.

# %%
#Create salesperson_revenue dictionary

salesperson_revenue = {}

def enter_revenue(name, revenue):
    global salesperson_revenue
    salesperson_revenue[name] = salesperson_revenue.get(name, 0) + revenue

while True:
    name = input("Enter the salesperson's name: ")
    if name == "çık":
        break
    revenue = int(input("Enter the revenue: "))
    enter_revenue(name, revenue)
    print(salesperson_revenue[name], "is the total revenue for", name)
# Out:
# Enter the salesperson's name: ali
# Enter the revenue: 5000
# 5000 is the total revenue for ali
# Enter the salesperson's name: zeynep
# Enter the revenue: 5500
# 5500 is the total revenue for zeynep
# Enter the salesperson's name: fatma
# Enter the revenue: 15000
# 15000 is the total revenue for fatma
# Enter the salesperson's name: serkan
# Enter the revenue: 7800
# 7800 is the total revenue for serkan
# Enter the salesperson's name: ahmet
# Enter the revenue: 50
# 50 is the total revenue for ahmet
# Enter the salesperson's name: merve
# Enter the revenue: 20000
# 20000 is the total revenue for merve
# Enter the salesperson's name: derin
# Enter the revenue: 2400
# 2400 is the total revenue for derin
# Enter the salesperson's name: çık

# %%
#Define enter_revenue function

# %% [markdown]
# ####Try out the functions
# * In a while loop ask the user to give the name of the employee and for the revenue
#
#   📌 If the user enters “quit” the loop should break.
#
# After that, print out the salesperson_revenue dictionary.

# %%
#Asking user employee name as input

# %%
#Print the salesperson_revenue dictionary

# %%
name = "johnny doe"

def func():
  global name
  name  = "john \n ndoe"

func()
print(name)
# Out:
# john
#  ndoe

# %%
person_list = {
    "omer" : 25,
    "winston" : 34,
    "jane" : 28,
    "robin" : 47
}
sum = 0

for i in person_list.values():
  if i >28:
    sum += i
    
print(sum)
# Out:
# 81

# %%
x = 27.5

if (int(x) == x):
   print(f" {int(x)} is equal to {x}" )
else:
  print(f" {int(x)} is not equal to {x}" )
# Out:
#  27 is not equal to 27.5
